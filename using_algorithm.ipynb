# %%
pip install streamlit
# Out:
# Requirement already satisfied: streamlit in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (1.46.1)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (6.1.0)
# Requirement already satisfied: click<9,>=7.0 in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (8.2.1)
# Requirement already satisfied: numpy<3,>=1.23 in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (2.3.1)
# Requirement already satisfied: packaging<26,>=20 in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (25.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (2.3.0)
# Requirement already satisfied: pillow<12,>=7.1.0 in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (11.3.0)
# Requirement already satisfied: protobuf<7,>=3.20 in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (6.31.1)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (20.0.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (2.32.4)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (4.14.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (3.1.44)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (6.5.1)
# Requirement already satisfied: jinja2 in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (from altair<6,>=4.0->streamlit) (4.24.0)
# Requirement already satisfied: narwhals>=1.14.2 in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (from altair<6,>=4.0->streamlit) (1.46.0)
# Requirement already satisfied: colorama in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.27->streamlit) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.27->streamlit) (2025.6.15)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.25.1)
# Requirement already satisfied: six>=1.5 in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import streamlit as st
import pandas as pd
import pickle

# Load the trained pipeline (Random Forest with preprocessing inside)
with open('car_price_model.pkl', 'rb') as f:
    model = pickle.load(f)

# Streamlit App Title
st.title("🚗 Car Price Prediction App")

st.write(
    """
    This app predicts the **estimated price** of a used car.
    
    Fill out the details below:
    """
)

# Input fields for user
company = st.text_input("Enter Company Name")
name = st.text_input("Enter Car Model Name")
year = st.number_input("Enter Year of Purchase", min_value=1990, max_value=2025, step=1)
kms_driven = st.number_input("Enter Kilometers Driven", min_value=0, step=500)
fuel_type = st.selectbox("Select Fuel Type", ["Petrol", "Diesel", "LPG"])

# Prediction Button
if st.button("Predict Price"):
    # Create input DataFrame with correct column order
    input_data = pd.DataFrame(
        [[company, name, year, kms_driven, fuel_type]],
        columns=["company", "name", "year", "kms_driven", "fuel_type"]
    )

    # Predict using the loaded model
    predicted_price = model.predict(input_data)[0]

    # Show result
    st.success(f"Estimated Car Price: ₹ {int(predicted_price):,}")
# Out:
# 2025-07-01 08:05:14.144 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-01 08:05:14.145 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-01 08:05:14.146 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-01 08:05:14.148 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-01 08:05:14.150 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-01 08:05:14.151 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-01 08:05:14.153 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-01 08:05:14.157 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-01 08:05:14.159 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-01 08:05:14.162 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-01 08:05:14.164 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-01 08:05:14.167 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-01 08:05:14.171 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-01 08:05:14.174 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-01 08:05:14.177 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-01 08:05:14.182 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-01 08:05:14.183 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-01 08:05:14.186 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-01 08:05:14.190 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-01 08:05:14.192 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-01 08:05:14.195 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-01 08:05:14.196 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-01 08:05:14.207 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-01 08:05:14.209 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-01 08:05:14.216 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-01 08:05:14.219 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-01 08:05:14.228 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-01 08:05:14.231 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-01 08:05:14.233 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-01 08:05:14.237 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-01 08:05:14.244 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-01 08:05:14.245 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-01 08:05:14.252 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-01 08:05:14.254 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-01 08:05:14.260 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-01 08:05:14.263 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-01 08:05:14.265 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-01 08:05:14.274 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-01 08:05:14.276 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-01 08:05:14.278 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-01 08:05:14.280 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-01 08:05:14.283 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-01 08:05:14.290 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-01 08:05:14.293 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-01 08:05:14.299 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-01 08:05:14.303 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-01 08:05:14.310 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
